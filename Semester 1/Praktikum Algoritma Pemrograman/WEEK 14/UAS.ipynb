# %%
pembeli = input("Masukkan nama Pembeli: ")
print ("Nama Pembeli :", pembeli) 

def fungsimakanan():
   global totalmkn
   global porsi
   global mkn
   print ("\n----------------- Menu Makanan -----------------")
   print("1. Nasi Goreng - Rp 15000")
   print("2. Soto - Rp 9000")
   print("3. Mie Ayam - Rp 11000")
   nomor=int(input("Masukan Pilihan: "))
   porsi= int(input("Berapa Porsi: "))
   
   if nomor==1:
       totalmkn=porsi*15000
       print (porsi," porsi Nasi Goreng Telur = Rp", totalmkn)
       mkn=("Nasi Goreng")
   elif nomor==2:
       totalmkn=porsi*9000
       print (porsi," porsi Soto = Rp", totalmkn)
       mkn=("Soto")
   elif nomor==3:
       totalmkn=porsi*11000
       print (porsi, " porsi Mie Ayam = Rp", totalmkn)
       mkn=("Mie Ayam")
   else:
      print("Pilihan tidak ada, silahkan masukan lagi!!")
      fungsimakanan()

def fungsiminuman():
   global totalmnm
   global mnm
   global gelas
   print("\n----------------- Menu Minuman -----------------")
   print("1. Es teh - Rp 2000")
   print("2. Es jeruk - Rp 3500")
   print("3. Es kopi - Rp 4000")
   nomor=int(input("Masukan Pilihan: "))
   gelas= int(input("Berapa Gelas: "))

   if nomor==1:
       totalmnm=gelas*2000
       print (gelas," Es Teh = Rp", totalmnm)
       mnm=(" Gelas Es Teh")
   elif nomor==2:
       totalmnm=gelas*3500
       print (gelas, " Gelas Es Jeruk = Rp", totalmnm)
       mnm=("Es Jeruk")
   elif nomor==3:
       totalmnm=gelas*4000
       print (gelas, " Gelas Es Kopi = Rp", totalmnm)
       mnm=("Es Kopi")
   else:
      print("Pilihan tidak ada, silahkan masukan lagi!!")
      fungsiminuman()

fungsimakanan()
fungsiminuman()
totalsemua=totalmkn+totalmnm

print("\nTotal harus Dibayar: Rp",totalsemua)
uang=int(input("Uang Tunai Pembeli: Rp "))
kembalian=int(uang-totalsemua)
print("Kembalian :",kembalian)

print("\n==================================")
print("========== S T R U K   B E L I =========")
print("==================================")
print ("Nama\t\t:",pembeli)
print ("Beli\t\t:",porsi,mkn,"( Rp", totalmkn,")")
print ("\t\t ",gelas,mnm,"( Rp", totalmnm,")")
print ("Tagihan\t\t: Rp",totalsemua)
print ("Dibayar\t\t: Rp",uang)
print ("Kembalian\t: Rp",kembalian)
print("==================================")
print("==================================")
# Out:
# ----------------- Program Kasir Sederhana Ekorkode -----------------
# Nama Pembeli : restu
#
# ----------------- Menu Makanan -----------------
# 1. Nasi Goreng - Rp 15000
# 2. Soto - Rp 9000
# 3. Mie Ayam - Rp 11000
# 2  porsi Nasi Goreng Telur = Rp 30000
#
# ----------------- Menu Minuman -----------------
# 1. Es teh - Rp 2000
# 2. Es jeruk - Rp 3500
# 3. Es kopi - Rp 4000
# 2  Es Teh = Rp 4000
#
# Total harus Dibayar: Rp 34000
# Kembalian : -14000
#
# ==================================
# ========== S T R U K   B E L I =========
# ==================================
# Nama		: restu
# Beli		: 2 Nasi Goreng ( Rp 30000 )
# 		  2  Gelas Es Teh ( Rp 4000 )
# Tagihan		: Rp 34000
# Dibayar		: Rp 20000
# Kembalian	: Rp -14000
# ==================================
# ==================================

# %%
from list import Kasir

def main():
    kasir = Kasir()

    while True:
        print("\nMenu:")
        print("1. Tambah Barang")
        print("2. Hapus Barang")
        print("3. Tampilkan Jumlah Barang")
        print("4. Tampilkan Nama Barang")
        print("0. Keluar")

        pilihan = input("Masukkan pilihan: ")

        if pilihan == "1":
            nama = input("Masukkan nama barang: ")
            tanggalkadaluarsa = input("Masukkan tanggal kadaluarsa (YYYY-MM-DD): ")
            kasir.tambah_barang(nama, tanggalkadaluarsa)

        elif pilihan == "2":
            nama = input("Masukkan nama barang yang ingin dihapus: ")
            kasir.hapus_barang(nama)

        elif pilihan == "3":
            kasir.tampilkan_jumlah_barang()

        elif pilihan == "4":
            print("nama: ", nama, "\ntanggal kadaluarsa: ", tanggalkadaluarsa)

        elif pilihan == "0":
            print("Program selesai.")
            break

        else:
            print("Pilihan tidak valid. Silakan coba lagi.")

if __name__ == "__main__":
    main()
# Out:
# Menu:
# 1. Tambah Barang
# 2. Hapus Barang
# 3. Tampilkan Jumlah Barang
# 4. Tampilkan Nama Barang
# 0. Keluar
# Barang sks berhasil ditambahkan!
#
# Menu:
# 1. Tambah Barang
# 2. Hapus Barang
# 3. Tampilkan Jumlah Barang
# 4. Tampilkan Nama Barang
# 0. Keluar
# Barang ags berhasil ditambahkan!
#
# Menu:
# 1. Tambah Barang
# 2. Hapus Barang
# 3. Tampilkan Jumlah Barang
# 4. Tampilkan Nama Barang
# 0. Keluar
# nama:  ags
# tanggal kadaluarsa:  1241-12-43
#
# Menu:
# 1. Tambah Barang
# 2. Hapus Barang
# 3. Tampilkan Jumlah Barang
# 4. Tampilkan Nama Barang
# 0. Keluar
# Program selesai.
